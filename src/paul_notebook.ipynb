# %% [markdown]
# # Projet STATISTIQUES - Étude de données météo

# %% [markdown]
# Groupe : Choquet Laura, Oncle Valentin, Laisné Paul, Maubian Joséphine, Regaieg Mohamed

# %% [markdown]
# ## Exploration et présentation des données
#
# Les données utilisées dans ce projet sont des données météorologiques provenant de la source suivante :
# https://public.opendatasoft.com/api/explore/v2.1/catalog/datasets/donnees-synop-essentielles-omm/exports/csv?lang=fr&qv1=(date%3A%5B2015-08-03T22%3A00%3A00Z%20TO%202025-09-03T21%3A59%3A59Z%5D)&timezone=Europe%2FBerlin&use_labels=true&delimiter=%3B

# %%
# Chargement du jeu de données
data <- read.csv("../data/station_7005_obs.csv", sep = ",") # Remplacer le lien par celui de votre jeu de données.

# %%
# Informations générales 
cat(strrep("-", 50), "\n")
cat("Dimension du dataset\n")
cat(strrep("-", 50), "\n")
dim_data <- dim(data)
cat("Nb d'observations :", dim_data[1], "\n")
cat("Nb de variables :", dim_data[2], "\n")
cat(strrep("-", 50), "\n")
cat("Liste des variables :\n")
cat(strrep("-", 50), "\n")
print(names(data))
# cat(strrep("-", 50), "\n")
# cat("Summary of the dataset\n")
# cat(strrep("-", 50), "\n")
# print(summary(data))
# Out:
# --------------------------------------------------
# Dimension du dataset
# --------------------------------------------------
# Nb d'observations : 29191
# Nb de variables : 62
# --------------------------------------------------
# Liste des variables :
# --------------------------------------------------
#  [1] "ID.OMM.station"
#  [2] "Date"
#  [3] "Pression.au.niveau.mer"
#  [4] "Variation.de.pression.en.3.heures"
#  [5] "Type.de.tendance.barométrique"
#  [6] "Direction.du.vent.moyen.10.mn"
#  [7] "Vitesse.du.vent.moyen.10.mn"
#  [8] "Température"
#  [9] "Point.de.rosée"
# [10] "Humidité"
# [11] "Visibilité.horizontale"
# [12] "Temps.présent"
# [13] "Temps.passé.1"
# [14] "Temps.passé.2"
# [15] "Nebulosité.totale"
# [16] "Nébulosité..des.nuages.de.l..étage.inférieur"
# [17] "Hauteur.de.la.base.des.nuages.de.l.étage.inférieur"
# [18] "Type.des.nuages.de.l.étage.inférieur"
# [19] "Type.des.nuages.de.l.étage.moyen"
# [20] "Type.des.nuages.de.l.étage.supérieur"
# [21] "Pression.station"
# [22] "Niveau.barométrique"
# [23] "Géopotentiel"
# [24] "Variation.de.pression.en.24.heures"
# [25] "Température.minimale.sur.12.heures"
# [26] "Température.minimale.sur.24.heures"
# [27] "Température.maximale.sur.12.heures"
# [28] "Température.maximale.sur.24.heures"
# [29] "Température.minimale.du.sol.sur.12.heures"
# [30] "Méthode.de.mesure.Température.du.thermomètre.mouillé"
# [31] "Température.du.thermomètre.mouillé"
# [32] "Rafale.sur.les.10.dernières.minutes"
# [33] "Rafales.sur.une.période"
# [34] "Periode.de.mesure.de.la.rafale"
# [35] "Etat.du.sol"
# [36] "Hauteur.totale.de.la.couche.de.neige..glace..autre.au.sol"
# [37] "Hauteur.de.la.neige.fraîche"
# [38] "Periode.de.mesure.de.la.neige.fraiche"
# [39] "Précipitations.dans.la.dernière.heure"
# [40] "Précipitations.dans.les.3.dernières.heures"
# [41] "Précipitations.dans.les.6.dernières.heures"
# [42] "Précipitations.dans.les.12.dernières.heures"
# [43] "Précipitations.dans.les.24.dernières.heures"
# [44] "Phénomène.spécial.4"
# [45] "Nébulosité.couche.nuageuse.1"
# [46] "Type.nuage.1"
# [47] "Hauteur.de.base.1"
# [48] "Nébulosité.couche.nuageuse.2"
# [49] "Type.nuage.2"
# [50] "Hauteur.de.base.2"
# [51] "Nébulosité.couche.nuageuse.3"
# [52] "Type.nuage.3"
# [53] "Hauteur.de.base.3"
# [54] "Nébulosité.couche.nuageuse.4"
# [55] "Type.nuage.4"
# [56] "Hauteur.de.base.4"
# [57] "Température.minimale.sur.12.heures...C."
# [58] "Température.minimale.sur.24.heures...C."
# [59] "Température.maximale.sur.12.heures...C."
# [60] "Température.maximale.sur.24.heures...C."
# [61] "Température.minimale.du.sol.sur.12.heures..en..C."
# [62] "mois_de_l_annee"

# %% [markdown]
# La sortie de la fonction summary() nous permet au préalable de constater que pour certaines variables il y a énormément de données manquantes. Afin d'avoir une meilleure visibilité sur le jeu de données et de réduire le nombre de variables sur lesquelles nous allons travaillé, nous avons d'abord écarté les variables non exploitables qui contiennent plus de 20 % de données manquantes.

# %%
# Analyse des données manquantes (en pourcentage)
missing_values_percent <- colMeans(is.na(data)) * 100
cat(strrep("-", 50), "\n")
cat("Analyse des données manquantes (en pourcentage)\n")
cat(strrep("-", 50), "\n")
print(round(missing_values_percent, 3))

# Affichage dans un histogramme des valeurs manquantes par colonne
par(bg = "white")
barplot(missing_values_percent, main = "Missing Values per Column", 
        xlab = "Columns", ylab = "Number of Missing Values", col = "blue", las = 2,
        names.arg = seq_along(missing_values_percent))
# Rajouter une ligne horizontale pour indiquer un seuil de tolérance
abline(h = 20, col = "red", lty = 2)
legend("topright", legend = "20% Threshold", col = "red", lty = 2)
# Out:
# --------------------------------------------------
# Analyse des données manquantes (en pourcentage)
# --------------------------------------------------
#                                            ID.OMM.station
#                                                     0.000
#                                                      Date
#                                                     0.000
#                                    Pression.au.niveau.mer
#                                                     0.041
#                         Variation.de.pression.en.3.heures
#                                                     0.055
#                             Type.de.tendance.barométrique
#                                                     0.055
#                             Direction.du.vent.moyen.10.mn
#                                                     0.130
#                               Vitesse.du.vent.moyen.10.mn
#                                                     0.130
#                                               Température
#                                                     0.003
#                                            Point.de.rosée
#                                                     0.003
#                                                  Humidité
#                                                     0.003
#                                    Visibilité.horizontale
#                                                     0.504
#                                             Temps.présent
#                                                     0.593
#                                             Temps.passé.1
#                                                    89.216
#                                             Temps.passé.2
#                                                    89.634
#                                         Nebulosité.totale
#                                                    89.709
#              Nébulosité..des.nuages.de.l..étage.inférieur
#                                                    89.709
#        Hauteur.de.la.base.des.nuages.de.l.étage.inférieur
#                                                    92.107
#                      Type.des.nuages.de.l.étage.inférieur
#                                                    89.709
#                          Type.des.nuages.de.l.étage.moyen
#                                                    93.563
#                      Type.des.nuages.de.l.étage.supérieur
#                                                    94.354
#                                          Pression.station
#                                                     0.041
#                                       Niveau.barométrique
#                                                   100.000
#                                              Géopotentiel
#                                                   100.000
#                        Variation.de.pression.en.24.heures
#                                                     0.277
#                        Température.minimale.sur.12.heures
#                                                    74.992
#                        Température.minimale.sur.24.heures
#                                                   100.000
#                        Température.maximale.sur.12.heures
#                                                    74.992
#                        Température.maximale.sur.24.heures
#                                                   100.000
#                 Température.minimale.du.sol.sur.12.heures
#                                                     1.048
#      Méthode.de.mesure.Température.du.thermomètre.mouillé
#                                                   100.000
#                        Température.du.thermomètre.mouillé
#                                                   100.000
#                       Rafale.sur.les.10.dernières.minutes
#                                                     0.305
#                                   Rafales.sur.une.période
#                                                     0.151
#                            Periode.de.mesure.de.la.rafale
#                                                     0.000
#                                               Etat.du.sol
#                                                    26.155
# Hauteur.totale.de.la.couche.de.neige..glace..autre.au.sol
#                                                     8.462
#                               Hauteur.de.la.neige.fraîche
#                                                    92.001
#                     Periode.de.mesure.de.la.neige.fraiche
#                                                    93.008
#                     Précipitations.dans.la.dernière.heure
#                                                     0.315
#                Précipitations.dans.les.3.dernières.heures
#                                                     0.349
#                Précipitations.dans.les.6.dernières.heures
#                                                     0.593
#               Précipitations.dans.les.12.dernières.heures
#                                                     0.846
#               Précipitations.dans.les.24.dernières.heures
#                                                     1.011
#                                       Phénomène.spécial.4
#                                                   100.000
#                              Nébulosité.couche.nuageuse.1
#                                                    90.093
#                                              Type.nuage.1
#                                                    90.093
#                                         Hauteur.de.base.1
#                                                    90.189
#                              Nébulosité.couche.nuageuse.2
#                                                    93.594
#                                              Type.nuage.2
#                                                    93.594
#                                         Hauteur.de.base.2
#                                                    93.594
#                              Nébulosité.couche.nuageuse.3
#                                                    97.677
#                                              Type.nuage.3
#                                                    97.677
#                                         Hauteur.de.base.3
#                                                    97.677
#                              Nébulosité.couche.nuageuse.4
#                                                    99.555
#                                              Type.nuage.4
#                                                    99.555
#                                         Hauteur.de.base.4
#                                                    99.555
#                   Température.minimale.sur.12.heures...C.
#                                                    74.992
#                   Température.minimale.sur.24.heures...C.
#                                                   100.000
#                   Température.maximale.sur.12.heures...C.
#                                                    74.992
#                   Température.maximale.sur.24.heures...C.
#                                                   100.000
#         Température.minimale.du.sol.sur.12.heures..en..C.
#                                                     1.048
#                                           mois_de_l_annee
#                                                     0.000
# Plot with title “Missing Values per Column”

# %%
# Suppression de colonnes avec plus de 20% de données manquantes
threshold_ratio <- 0.2
threshold <- threshold_ratio * nrow(data)
missing_values <- colSums(is.na(data))
columns_to_drop <- names(missing_values[missing_values > threshold])
data_cleaned <- data[, !(names(data) %in% columns_to_drop)]
cat(strrep("-", 50), "\n")
cat("Colonnes supprimées (plus de 20% de données manquantes) :\n")
cat(strrep("-", 50), "\n")
print(columns_to_drop)
cat(strrep("-", 50), "\n")
cat("Dimension du dataset après suppression des colonnes :\n")
cat(strrep("-", 50), "\n")
dim_data_cleaned <- dim(data_cleaned)
cat("Nb d'observations :", dim_data_cleaned[1], "\n")
cat("Nb de variables :", dim_data_cleaned[2], "\n")
cat(strrep("-", 50), "\n")
cat("Liste des variables après nettoyage :\n")
print(names(data_cleaned))
# Out:
# --------------------------------------------------
# Colonnes supprimées (plus de 20% de données manquantes) :
# --------------------------------------------------
#  [1] "Temps.passé.1"
#  [2] "Temps.passé.2"
#  [3] "Nebulosité.totale"
#  [4] "Nébulosité..des.nuages.de.l..étage.inférieur"
#  [5] "Hauteur.de.la.base.des.nuages.de.l.étage.inférieur"
#  [6] "Type.des.nuages.de.l.étage.inférieur"
#  [7] "Type.des.nuages.de.l.étage.moyen"
#  [8] "Type.des.nuages.de.l.étage.supérieur"
#  [9] "Niveau.barométrique"
# [10] "Géopotentiel"
# [11] "Température.minimale.sur.12.heures"
# [12] "Température.minimale.sur.24.heures"
# [13] "Température.maximale.sur.12.heures"
# [14] "Température.maximale.sur.24.heures"
# [15] "Méthode.de.mesure.Température.du.thermomètre.mouillé"
# [16] "Température.du.thermomètre.mouillé"
# [17] "Etat.du.sol"
# [18] "Hauteur.de.la.neige.fraîche"
# [19] "Periode.de.mesure.de.la.neige.fraiche"
# [20] "Phénomène.spécial.4"
# [21] "Nébulosité.couche.nuageuse.1"
# [22] "Type.nuage.1"
# [23] "Hauteur.de.base.1"
# [24] "Nébulosité.couche.nuageuse.2"
# [25] "Type.nuage.2"
# [26] "Hauteur.de.base.2"
# [27] "Nébulosité.couche.nuageuse.3"
# [28] "Type.nuage.3"
# [29] "Hauteur.de.base.3"
# [30] "Nébulosité.couche.nuageuse.4"
# [31] "Type.nuage.4"
# [32] "Hauteur.de.base.4"
# [33] "Température.minimale.sur.12.heures...C."
# [34] "Température.minimale.sur.24.heures...C."
# [35] "Température.maximale.sur.12.heures...C."
# [36] "Température.maximale.sur.24.heures...C."
# --------------------------------------------------
# Dimension du dataset après suppression des colonnes :
# --------------------------------------------------
# Nb d'observations : 29191
# Nb de variables : 26
# --------------------------------------------------
# Liste des variables après nettoyage :
#  [1] "ID.OMM.station"
#  [2] "Date"
#  [3] "Pression.au.niveau.mer"
#  [4] "Variation.de.pression.en.3.heures"
#  [5] "Type.de.tendance.barométrique"
#  [6] "Direction.du.vent.moyen.10.mn"
#  [7] "Vitesse.du.vent.moyen.10.mn"
#  [8] "Température"
#  [9] "Point.de.rosée"
# [10] "Humidité"
# [11] "Visibilité.horizontale"
# [12] "Temps.présent"
# [13] "Pression.station"
# [14] "Variation.de.pression.en.24.heures"
# [15] "Température.minimale.du.sol.sur.12.heures"
# [16] "Rafale.sur.les.10.dernières.minutes"
# [17] "Rafales.sur.une.période"
# [18] "Periode.de.mesure.de.la.rafale"
# [19] "Hauteur.totale.de.la.couche.de.neige..glace..autre.au.sol"
# [20] "Précipitations.dans.la.dernière.heure"
# [21] "Précipitations.dans.les.3.dernières.heures"
# [22] "Précipitations.dans.les.6.dernières.heures"
# [23] "Précipitations.dans.les.12.dernières.heures"
# [24] "Précipitations.dans.les.24.dernières.heures"
# [25] "Température.minimale.du.sol.sur.12.heures..en..C."
# [26] "mois_de_l_annee"

# %%
# Récupération des variables numériques
# On considère les variables date, ID.OMM.station comme catégorielle
categorical_var = c("Date", "ID.OMM.station", "Point.de.rosée", "Pression.au.niveau.mer", "Periode.de.mesure.de.la.rafale", "Hauteur.totale.de.la.couche.de.neige..glace..autre.au.sol", "mois_de_l_annee", "Température.minimale.du.sol.sur.12.heures", "Rafales.sur.une.période", "Température.minimale.du.sol.sur.12.heures..en..C.", "Rafale.sur.les.10.dernières.minutes", "Précipitations.dans.les.6.dernières.heures", "Précipitations.dans.les.12.dernières.heures", "Précipitations.dans.la.dernière.heure", "Type.de.tendance.barométrique")
data_numeric <- data_cleaned[, !(names(data_cleaned) %in% categorical_var)]

cat(strrep("-", 50), "\n")
cat("Variables numériques :\n")
cat(strrep("-", 50), "\n")
cat("Nb de variables :", length(names(data_numeric)), "\n")
print(names(data_numeric))
cat(strrep("-", 50), "\n")
# Out:
# --------------------------------------------------
# Variables numériques :
# --------------------------------------------------
# Nb de variables : 11
#  [1] "Variation.de.pression.en.3.heures"
#  [2] "Direction.du.vent.moyen.10.mn"
#  [3] "Vitesse.du.vent.moyen.10.mn"
#  [4] "Température"
#  [5] "Humidité"
#  [6] "Visibilité.horizontale"
#  [7] "Temps.présent"
#  [8] "Pression.station"
#  [9] "Variation.de.pression.en.24.heures"
# [10] "Précipitations.dans.les.3.dernières.heures"
# [11] "Précipitations.dans.les.24.dernières.heures"
# --------------------------------------------------

# %%
# Affichage graphique de la matrice de corrélation
# Afficher les indices et les noms des colonnes
cat("Indices et noms des colonnes :\n")
for (i in seq_along(names(data_numeric))) {
    cat(i, ":", names(data_numeric)[i], "\n")
}
# Remplacer les noms des colonnes par leurs indices dans la matrice de corrélation
library(corrplot)
par(bg = "white")

cor_matrix <- cor(data_numeric, use = "pairwise.complete.obs")
colnames(cor_matrix) <- rownames(cor_matrix) <- seq_len(ncol(cor_matrix))
corrplot(cor_matrix, method = "color")

# Print les 5 paires de variables les plus corrélées
cor_matrix[lower.tri(cor_matrix, diag = TRUE)] <- NA
cor_values <- as.data.frame(as.table(cor_matrix))
cor_values <- na.omit(cor_values)
cor_values <- cor_values[order(-abs(cor_values$Freq)), ]
cat(strrep("-", 50), "\n")
cat("10 paires de variables les plus corrélées :\n")
cat(strrep("-", 50), "\n")
for (i in 1:10) {
    var1_index <- cor_values[i, 1]
    var2_index <- cor_values[i, 2]
    var1_name <- names(data_numeric)[as.numeric(var1_index)]
    var2_name <- names(data_numeric)[as.numeric(var2_index)]
    cat(paste0(i, ". ", var1_name, " et ", var2_name, " : ", round(cor_values[i, 3], 3), "\n"))
}
cat(strrep("-", 50), "\n")
# Out:
# Indices et noms des colonnes :
# 1 : Variation.de.pression.en.3.heures
# 2 : Direction.du.vent.moyen.10.mn
# 3 : Vitesse.du.vent.moyen.10.mn
# 4 : Température
# 5 : Humidité
# 6 : Visibilité.horizontale
# 7 : Temps.présent
# 8 : Pression.station
# 9 : Variation.de.pression.en.24.heures
# 10 : Précipitations.dans.les.3.dernières.heures
# 11 : Précipitations.dans.les.24.dernières.heures
# Warning message in plot.window(...):
# “"method" n'est pas un paramètre graphique”
# Warning message in plot.xy(xy, type, ...):
# “"method" n'est pas un paramètre graphique”
# Warning message in axis(side = side, at = at, labels = labels, ...):
# “"method" n'est pas un paramètre graphique”
# Warning message in axis(side = side, at = at, labels = labels, ...):
# “"method" n'est pas un paramètre graphique”
# Warning message in box(...):
# “"method" n'est pas un paramètre graphique”
# Warning message in title(...):
# “"method" n'est pas un paramètre graphique”
# --------------------------------------------------
# 10 paires de variables les plus corrélées :
# --------------------------------------------------
# 1. Humidité et Visibilité.horizontale : -0.514
# 2. Température et Humidité : -0.508
# 3. Variation.de.pression.en.3.heures et Variation.de.pression.en.24.heures : 0.489
# 4. Précipitations.dans.les.3.dernières.heures et Précipitations.dans.les.24.dernières.heures : 0.444
# 5. Visibilité.horizontale et Temps.présent : -0.426
# 6. Temps.présent et Précipitations.dans.les.3.dernières.heures : 0.393
# 7. Pression.station et Précipitations.dans.les.24.dernières.heures : -0.36
# 8. Pression.station et Variation.de.pression.en.24.heures : 0.34
# 9. Température et Visibilité.horizontale : 0.321
# 10. Humidité et Temps.présent : 0.302
# --------------------------------------------------
# plot without title

# %% [markdown]
# ## Calcul et étude d'un estimateur

# %% [markdown]
# ## Tests sur un paramètre et ANOVA

# %% [markdown]
# ## Régression et corrélation

# %% [markdown]
# ## ACP et PLS

# %%
length(names(data_numeric))
# Out:
# [1] 11

# %%
library(pls)
?pls
# Out:
# pls                    package:pls                     R Documentation
#
# n
#
# n:
#
#      Multivariate regression methods Partial Least Squares Regression
#      (PLSR), Principal Component Regression (PCR) and Canonical Powered
#      Partial Least Squares (CPPLS).
#
# s):
#
#      *Maintainer*: Kristian Hovde Liland
#      <mailto:kristian.liland@nmbu.no>
#
#      Authors:
#
#         • Bjørn-Helge Mevik <mailto:b-h@mevik.net>
#
#         • Ron Wehrens
#
#      Other contributors:
#
#         • Paul Hiemstra [contributor]
#
# o:
#
#      Useful links:
#
#         • <https://github.com/khliland/pls>
#
#         • Report bugs at <https://github.com/khliland/pls/issues>

# %%
# Utiliser le nom exact de la variable cible
target_var <- "Humidité"


# Créer un data.frame avec toutes les variables nécessaires
df_pls <- data_numeric[, c(target_var, setdiff(names(data_numeric), target_var))]
df_pls <- na.omit(df_pls) # Retirer toutes les lignes avec NA

y <- df_pls[[target_var]]
X <- df_pls[, setdiff(names(df_pls), target_var), drop = FALSE]

# Régression PLS avec validation croisée
pls_model <- plsr(y ~ as.matrix(X), validation = "CV")

# Résumé du modèle
summary(pls_model)

# Sélection du nombre optimal de composantes
par(bg = 'white')
validationplot(pls_model, val.type = "MSEP")

# Trouver le nombre optimal de composantes
opt_ncomp <- which.min(pls_model$validation$PRESS)

ncomp = 7

# Prédictions
pred <- predict(pls_model, ncomp = opt_ncomp)
pred_vec <- as.vector(pred[,1,1])

# Plot prédiction vs ground truth
par(pty = "s")
plot_lim <- range(c(y, pred_vec))
plot(y, pred_vec, 
     xlab = "Valeurs réelles", 
     ylab = "Prédictions PLS", 
     main = paste("Prédictions vs valeurs réelles (PLS) avec", opt_ncomp, "composantes"), 
     col = "blue", pch = 16,
     xlim = plot_lim, ylim = plot_lim)

abline(a = 0, b = 1, col = "red", lwd = 2)

# Affichage des coefficients et les indices des variables dans X
coef(pls_model, ncomp = opt_ncomp)
# Out:
# Data: 	X dimension: 28598 10
# 	Y dimension: 28598 1
# Fit method: kernelpls
# Number of components considered: 10
#
# VALIDATION: RMSEP
# Cross-validated using 10 random segments.
#        (Intercept)  1 comps  2 comps  3 comps  4 comps  5 comps  6 comps
# CV              15    12.87    12.72    12.66    12.51    12.49    11.69
# adjCV           15    12.87    12.72    12.66    12.51    12.49    11.69
#        7 comps  8 comps  9 comps  10 comps
# CV       11.01    10.63    10.55     10.53
# adjCV    11.01    10.63    10.55     10.53
#
# TRAINING: % variance explained
#    1 comps  2 comps  3 comps  4 comps  5 comps  6 comps  7 comps  8 comps
# X    97.03    98.83    99.95    99.98   100.00   100.00   100.00   100.00
# y    26.46    28.19    28.79    30.46    30.75    39.36    46.19    49.88
#    9 comps  10 comps
# X    100.0    100.00
# y     50.6     50.75
# Plot with title “y”
# , , 10 comps
#
#                                                                     y
# as.matrix(X)Variation.de.pression.en.3.heures            0.0069729359
# as.matrix(X)Direction.du.vent.moyen.10.mn                0.0272382827
# as.matrix(X)Vitesse.du.vent.moyen.10.mn                 -1.6898027147
# as.matrix(X)Température                                 -0.9280148054
# as.matrix(X)Visibilité.horizontale                      -0.0007319268
# as.matrix(X)Temps.présent                                0.0419897835
# as.matrix(X)Pression.station                            -0.0012200926
# as.matrix(X)Variation.de.pression.en.24.heures          -0.0005241698
# as.matrix(X)Précipitations.dans.les.3.dernières.heures   0.8586060540
# as.matrix(X)Précipitations.dans.les.24.dernières.heures  0.3192898878
# Plot with title “Prédictions vs valeurs réelles (PLS) avec 10 composantes”

# %%
# Récupérer les loadings (combinaisons linéaires) des composantes PLS
loadings_pls <- loadings(pls_model)

# Afficher les loadings pour les premières composantes
print("Loadings des composantes PLS:")
print(loadings_pls[, 1:min(ncomp)])

# Boucle pour chaque composante
for (i in 1:min(ncomp)) {
        # Pour voir comment chaque variable contribue à une composante spécifique
        cat("\nContribution des variables à la composante", i, ":\n")
        comp1_loadings <- loadings_pls[, i]
        names(comp1_loadings) <- colnames(X)
        print(sort(abs(comp1_loadings), decreasing = TRUE))

        # Afficher graphiquement les loadings de la première composante
        par(bg = 'white')
        barplot(comp1_loadings, 
                main = paste("Loadings de la Composante", i, "PLS"),
                las = 2, 
                col = "lightblue",
                cex.names = 0.7)

}

# # Pour récupérer les scores (valeurs des composantes pour chaque observation)
# scores_pls <- scores(pls_model)
# cat("\nDimensions des scores:", dim(scores_pls), "\n")

# # Exemple : afficher la première composante pour les 10 premières observations
# cat("Première composante pour les 10 premières observations:\n")
# print(scores_pls[1:10, 1])
# Out:
# [1] "Loadings des composantes PLS:"
#                                                                      Comp 1
# as.matrix(X)Variation.de.pression.en.3.heures                 -2.171091e-04
# as.matrix(X)Type.de.tendance.barométrique                      2.367758e-06
# as.matrix(X)Direction.du.vent.moyen.10.mn                     -1.469400e-03
# as.matrix(X)Vitesse.du.vent.moyen.10.mn                       -5.730090e-05
# as.matrix(X)Température                                       -2.929742e-04
# as.matrix(X)Point.de.rosée                                    -6.587599e-05
# as.matrix(X)Visibilité.horizontale                            -1.000393e+00
# as.matrix(X)Temps.présent                                      1.094684e-03
# as.matrix(X)Pression.station                                   1.271812e-02
# as.matrix(X)Variation.de.pression.en.24.heures                -4.465809e-03
# as.matrix(X)Rafale.sur.les.10.dernières.minutes               -1.075793e-04
# as.matrix(X)Rafales.sur.une.période                           -1.206648e-04
# as.matrix(X)Précipitations.dans.la.dernière.heure              1.092696e-05
# as.matrix(X)Précipitations.dans.les.3.dernières.heures         2.222988e-05
# as.matrix(X)Précipitations.dans.les.6.dernières.heures         2.922801e-05
# as.matrix(X)Précipitations.dans.les.12.dernières.heures        3.287643e-05
# as.matrix(X)Précipitations.dans.les.24.dernières.heures        2.742585e-05
# as.matrix(X)Température.minimale.du.sol.sur.12.heures..en..C. -1.362728e-04
#                                                                      Comp 2
# as.matrix(X)Variation.de.pression.en.3.heures                  1.568439e-02
# as.matrix(X)Type.de.tendance.barométrique                     -2.932565e-04
# as.matrix(X)Direction.du.vent.moyen.10.mn                      1.582198e-02
# as.matrix(X)Vitesse.du.vent.moyen.10.mn                        4.271356e-04
# as.matrix(X)Température                                       -9.912084e-06
# as.matrix(X)Point.de.rosée                                     5.184091e-04
# as.matrix(X)Visibilité.horizontale                             1.710954e-02
# as.matrix(X)Temps.présent                                      3.948099e-03
# as.matrix(X)Pression.station                                  -1.117542e+00
# as.matrix(X)Variation.de.pression.en.24.heures                -3.927116e-02
# as.matrix(X)Rafale.sur.les.10.dernières.minutes                1.069593e-03
# as.matrix(X)Rafales.sur.une.période                            1.274465e-03
# as.matrix(X)Précipitations.dans.la.dernière.heure              9.700631e-05
# as.matrix(X)Précipitations.dans.les.3.dernières.heures         2.978242e-04
# as.matrix(X)Précipitations.dans.les.6.dernières.heures         5.847678e-04
# as.matrix(X)Précipitations.dans.les.12.dernières.heures        1.123451e-03
# as.matrix(X)Précipitations.dans.les.24.dernières.heures        2.127864e-03
# as.matrix(X)Température.minimale.du.sol.sur.12.heures..en..C.  4.067614e-04
#                                                                      Comp 3
# as.matrix(X)Variation.de.pression.en.3.heures                  9.775371e-02
# as.matrix(X)Type.de.tendance.barométrique                     -1.539777e-03
# as.matrix(X)Direction.du.vent.moyen.10.mn                      2.117288e-02
# as.matrix(X)Vitesse.du.vent.moyen.10.mn                       -2.953752e-04
# as.matrix(X)Température                                       -1.130855e-03
# as.matrix(X)Point.de.rosée                                    -7.109795e-04
# as.matrix(X)Visibilité.horizontale                             1.055027e-03
# as.matrix(X)Temps.présent                                     -2.422327e-03
# as.matrix(X)Pression.station                                   4.171920e-01
# as.matrix(X)Variation.de.pression.en.24.heures                 9.396090e-01
# as.matrix(X)Rafale.sur.les.10.dernières.minutes               -7.900831e-04
# as.matrix(X)Rafales.sur.une.période                           -8.776136e-04
# as.matrix(X)Précipitations.dans.la.dernière.heure             -5.616351e-05
# as.matrix(X)Précipitations.dans.les.3.dernières.heures        -1.795966e-04
# as.matrix(X)Précipitations.dans.les.6.dernières.heures        -3.169516e-04
# as.matrix(X)Précipitations.dans.les.12.dernières.heures       -4.035874e-04
# as.matrix(X)Précipitations.dans.les.24.dernières.heures        2.051031e-04
# as.matrix(X)Température.minimale.du.sol.sur.12.heures..en..C. -6.078520e-04
#                                                                      Comp 4
# as.matrix(X)Variation.de.pression.en.3.heures                  0.6952967605
# as.matrix(X)Type.de.tendance.barométrique                     -0.0095947986
# as.matrix(X)Direction.du.vent.moyen.10.mn                      0.6744651158
# as.matrix(X)Vitesse.du.vent.moyen.10.mn                        0.0042559957
# as.matrix(X)Température                                        0.0020100185
# as.matrix(X)Point.de.rosée                                     0.0063105505
# as.matrix(X)Visibilité.horizontale                             0.0009617978
# as.matrix(X)Temps.présent                                      0.0062439007
# as.matrix(X)Pression.station                                   0.0326483829
# as.matrix(X)Variation.de.pression.en.24.heures                -0.3773459853
# as.matrix(X)Rafale.sur.les.10.dernières.minutes                0.0054734834
# as.matrix(X)Rafales.sur.une.période                            0.0066713274
# as.matrix(X)Précipitations.dans.la.dernière.heure              0.0001402942
# as.matrix(X)Précipitations.dans.les.3.dernières.heures         0.0006769612
# as.matrix(X)Précipitations.dans.les.6.dernières.heures         0.0021557615
# as.matrix(X)Précipitations.dans.les.12.dernières.heures        0.0053829365
# as.matrix(X)Précipitations.dans.les.24.dernières.heures        0.0080222971
# as.matrix(X)Température.minimale.du.sol.sur.12.heures..en..C.  0.0061476373
#                                                                      Comp 5
# as.matrix(X)Variation.de.pression.en.3.heures                 -1.1029859828
# as.matrix(X)Type.de.tendance.barométrique                      0.0143968279
# as.matrix(X)Direction.du.vent.moyen.10.mn                      0.7687048435
# as.matrix(X)Vitesse.du.vent.moyen.10.mn                       -0.0005500968
# as.matrix(X)Température                                        0.0041084290
# as.matrix(X)Point.de.rosée                                     0.0062451076
# as.matrix(X)Visibilité.horizontale                            -0.0014031205
# as.matrix(X)Temps.présent                                      0.0386101668
# as.matrix(X)Pression.station                                  -0.0080364203
# as.matrix(X)Variation.de.pression.en.24.heures                 0.1011346985
# as.matrix(X)Rafale.sur.les.10.dernières.minutes                0.0015436085
# as.matrix(X)Rafales.sur.une.période                            0.0014798316
# as.matrix(X)Précipitations.dans.la.dernière.heure              0.0005760353
# as.matrix(X)Précipitations.dans.les.3.dernières.heures         0.0011050773
# as.matrix(X)Précipitations.dans.les.6.dernières.heures         0.0005997801
# as.matrix(X)Précipitations.dans.les.12.dernières.heures       -0.0014877473
# as.matrix(X)Précipitations.dans.les.24.dernières.heures       -0.0010213340
# as.matrix(X)Température.minimale.du.sol.sur.12.heures..en..C.  0.0006803705
#                                                                     Comp 6
# as.matrix(X)Variation.de.pression.en.3.heures                  0.483971011
# as.matrix(X)Type.de.tendance.barométrique                     -0.012674350
# as.matrix(X)Direction.du.vent.moyen.10.mn                     -0.525523732
# as.matrix(X)Vitesse.du.vent.moyen.10.mn                       -0.036538481
# as.matrix(X)Température                                       -0.352493233
# as.matrix(X)Point.de.rosée                                    -0.232818658
# as.matrix(X)Visibilité.horizontale                             0.002202421
# as.matrix(X)Temps.présent                                      1.035606380
# as.matrix(X)Pression.station                                   0.004346005
# as.matrix(X)Variation.de.pression.en.24.heures                -0.038640764
# as.matrix(X)Rafale.sur.les.10.dernières.minutes               -0.058831288
# as.matrix(X)Rafales.sur.une.période                           -0.058557888
# as.matrix(X)Précipitations.dans.la.dernière.heure              0.011017186
# as.matrix(X)Précipitations.dans.les.3.dernières.heures         0.027770777
# as.matrix(X)Précipitations.dans.les.6.dernières.heures         0.042924107
# as.matrix(X)Précipitations.dans.les.12.dernières.heures        0.064966198
# as.matrix(X)Précipitations.dans.les.24.dernières.heures        0.092822429
# as.matrix(X)Température.minimale.du.sol.sur.12.heures..en..C. -0.248901395
#                                                                     Comp 7
# as.matrix(X)Variation.de.pression.en.3.heures                 -0.016707901
# as.matrix(X)Type.de.tendance.barométrique                     -0.004491578
# as.matrix(X)Direction.du.vent.moyen.10.mn                      0.035673273
# as.matrix(X)Vitesse.du.vent.moyen.10.mn                       -0.107534794
# as.matrix(X)Température                                       -0.342894884
# as.matrix(X)Point.de.rosée                                    -0.195454059
# as.matrix(X)Visibilité.horizontale                            -0.001108389
# as.matrix(X)Temps.présent                                     -1.097701389
# as.matrix(X)Pression.station                                  -0.004182670
# as.matrix(X)Variation.de.pression.en.24.heures                -0.001124071
# as.matrix(X)Rafale.sur.les.10.dernières.minutes               -0.183613415
# as.matrix(X)Rafales.sur.une.période                           -0.198988662
# as.matrix(X)Précipitations.dans.la.dernière.heure             -0.010692291
# as.matrix(X)Précipitations.dans.les.3.dernières.heures        -0.017843161
# as.matrix(X)Précipitations.dans.les.6.dernières.heures        -0.016338679
# as.matrix(X)Précipitations.dans.les.12.dernières.heures       -0.006046974
# as.matrix(X)Précipitations.dans.les.24.dernières.heures        0.013552382
# as.matrix(X)Température.minimale.du.sol.sur.12.heures..en..C. -0.200671672
#
# Contribution des variables à la composante 1 :
#                            Visibilité.horizontale
#                                      1.000393e+00
#                                  Pression.station
#                                      1.271812e-02
#                Variation.de.pression.en.24.heures
#                                      4.465809e-03
#                     Direction.du.vent.moyen.10.mn
#                                      1.469400e-03
#                                     Temps.présent
#                                      1.094684e-03
#                                       Température
#                                      2.929742e-04
#                 Variation.de.pression.en.3.heures
#                                      2.171091e-04
# Température.minimale.du.sol.sur.12.heures..en..C.
#                                      1.362728e-04
#                           Rafales.sur.une.période
#                                      1.206648e-04
#               Rafale.sur.les.10.dernières.minutes
#                                      1.075793e-04
#                                    Point.de.rosée
#                                      6.587599e-05
#                       Vitesse.du.vent.moyen.10.mn
#                                      5.730090e-05
#       Précipitations.dans.les.12.dernières.heures
#                                      3.287643e-05
#        Précipitations.dans.les.6.dernières.heures
#                                      2.922801e-05
#       Précipitations.dans.les.24.dernières.heures
#                                      2.742585e-05
#        Précipitations.dans.les.3.dernières.heures
#                                      2.222988e-05
#             Précipitations.dans.la.dernière.heure
#                                      1.092696e-05
#                     Type.de.tendance.barométrique
#                                      2.367758e-06
#
# Contribution des variables à la composante 2 :
#                                  Pression.station
#                                      1.117542e+00
#                Variation.de.pression.en.24.heures
#                                      3.927116e-02
#                            Visibilité.horizontale
#                                      1.710954e-02
#                     Direction.du.vent.moyen.10.mn
#                                      1.582198e-02
#                 Variation.de.pression.en.3.heures
#                                      1.568439e-02
#                                     Temps.présent
#                                      3.948099e-03
#       Précipitations.dans.les.24.dernières.heures
#                                      2.127864e-03
#                           Rafales.sur.une.période
#                                      1.274465e-03
#       Précipitations.dans.les.12.dernières.heures
#                                      1.123451e-03
#               Rafale.sur.les.10.dernières.minutes
#                                      1.069593e-03
#        Précipitations.dans.les.6.dernières.heures
#                                      5.847678e-04
#                                    Point.de.rosée
#                                      5.184091e-04
#                       Vitesse.du.vent.moyen.10.mn
#                                      4.271356e-04
# Température.minimale.du.sol.sur.12.heures..en..C.
#                                      4.067614e-04
#        Précipitations.dans.les.3.dernières.heures
#                                      2.978242e-04
#                     Type.de.tendance.barométrique
#                                      2.932565e-04
#             Précipitations.dans.la.dernière.heure
#                                      9.700631e-05
#                                       Température
#                                      9.912084e-06
# Plot with title “Loadings de la Composante 1 PLS”
# Contribution des variables à la composante 3 :
#                Variation.de.pression.en.24.heures
#                                      9.396090e-01
#                                  Pression.station
#                                      4.171920e-01
#                 Variation.de.pression.en.3.heures
#                                      9.775371e-02
#                     Direction.du.vent.moyen.10.mn
#                                      2.117288e-02
#                                     Temps.présent
#                                      2.422327e-03
#                     Type.de.tendance.barométrique
#                                      1.539777e-03
#                                       Température
#                                      1.130855e-03
#                            Visibilité.horizontale
#                                      1.055027e-03
#                           Rafales.sur.une.période
#                                      8.776136e-04
#               Rafale.sur.les.10.dernières.minutes
#                                      7.900831e-04
#                                    Point.de.rosée
#                                      7.109795e-04
# Température.minimale.du.sol.sur.12.heures..en..C.
#                                      6.078520e-04
#       Précipitations.dans.les.12.dernières.heures
#                                      4.035874e-04
#        Précipitations.dans.les.6.dernières.heures
#                                      3.169516e-04
#                       Vitesse.du.vent.moyen.10.mn
#                                      2.953752e-04
#       Précipitations.dans.les.24.dernières.heures
#                                      2.051031e-04
#        Précipitations.dans.les.3.dernières.heures
#                                      1.795966e-04
#             Précipitations.dans.la.dernière.heure
#                                      5.616351e-05
# Plot with title “Loadings de la Composante 2 PLS”
# Contribution des variables à la composante 4 :
#                 Variation.de.pression.en.3.heures
#                                      0.6952967605
#                     Direction.du.vent.moyen.10.mn
#                                      0.6744651158
#                Variation.de.pression.en.24.heures
#                                      0.3773459853
#                                  Pression.station
#                                      0.0326483829
#                     Type.de.tendance.barométrique
#                                      0.0095947986
#       Précipitations.dans.les.24.dernières.heures
#                                      0.0080222971
#                           Rafales.sur.une.période
#                                      0.0066713274
#                                    Point.de.rosée
#                                      0.0063105505
#                                     Temps.présent
#                                      0.0062439007
# Température.minimale.du.sol.sur.12.heures..en..C.
#                                      0.0061476373
#               Rafale.sur.les.10.dernières.minutes
#                                      0.0054734834
#       Précipitations.dans.les.12.dernières.heures
#                                      0.0053829365
#                       Vitesse.du.vent.moyen.10.mn
#                                      0.0042559957
#        Précipitations.dans.les.6.dernières.heures
#                                      0.0021557615
#                                       Température
#                                      0.0020100185
#                            Visibilité.horizontale
#                                      0.0009617978
#        Précipitations.dans.les.3.dernières.heures
#                                      0.0006769612
#             Précipitations.dans.la.dernière.heure
#                                      0.0001402942
# Plot with title “Loadings de la Composante 3 PLS”
# Contribution des variables à la composante 5 :
#                 Variation.de.pression.en.3.heures
#                                      1.1029859828
#                     Direction.du.vent.moyen.10.mn
#                                      0.7687048435
#                Variation.de.pression.en.24.heures
#                                      0.1011346985
#                                     Temps.présent
#                                      0.0386101668
#                     Type.de.tendance.barométrique
#                                      0.0143968279
#                                  Pression.station
#                                      0.0080364203
#                                    Point.de.rosée
#                                      0.0062451076
#                                       Température
#                                      0.0041084290
#               Rafale.sur.les.10.dernières.minutes
#                                      0.0015436085
#       Précipitations.dans.les.12.dernières.heures
#                                      0.0014877473
#                           Rafales.sur.une.période
#                                      0.0014798316
#                            Visibilité.horizontale
#                                      0.0014031205
#        Précipitations.dans.les.3.dernières.heures
#                                      0.0011050773
#       Précipitations.dans.les.24.dernières.heures
#                                      0.0010213340
# Température.minimale.du.sol.sur.12.heures..en..C.
#                                      0.0006803705
#        Précipitations.dans.les.6.dernières.heures
#                                      0.0005997801
#             Précipitations.dans.la.dernière.heure
#                                      0.0005760353
#                       Vitesse.du.vent.moyen.10.mn
#                                      0.0005500968
# Plot with title “Loadings de la Composante 4 PLS”
# Contribution des variables à la composante 6 :
#                                     Temps.présent
#                                       1.035606380
#                     Direction.du.vent.moyen.10.mn
#                                       0.525523732
#                 Variation.de.pression.en.3.heures
#                                       0.483971011
#                                       Température
#                                       0.352493233
# Température.minimale.du.sol.sur.12.heures..en..C.
#                                       0.248901395
#                                    Point.de.rosée
#                                       0.232818658
#       Précipitations.dans.les.24.dernières.heures
#                                       0.092822429
#       Précipitations.dans.les.12.dernières.heures
#                                       0.064966198
#               Rafale.sur.les.10.dernières.minutes
#                                       0.058831288
#                           Rafales.sur.une.période
#                                       0.058557888
#        Précipitations.dans.les.6.dernières.heures
#                                       0.042924107
#                Variation.de.pression.en.24.heures
#                                       0.038640764
#                       Vitesse.du.vent.moyen.10.mn
#                                       0.036538481
#        Précipitations.dans.les.3.dernières.heures
#                                       0.027770777
#                     Type.de.tendance.barométrique
#                                       0.012674350
#             Précipitations.dans.la.dernière.heure
#                                       0.011017186
#                                  Pression.station
#                                       0.004346005
#                            Visibilité.horizontale
#                                       0.002202421
# Plot with title “Loadings de la Composante 5 PLS”
# Contribution des variables à la composante 7 :
#                                     Temps.présent
#                                       1.097701389
#                                       Température
#                                       0.342894884
# Température.minimale.du.sol.sur.12.heures..en..C.
#                                       0.200671672
#                           Rafales.sur.une.période
#                                       0.198988662
#                                    Point.de.rosée
#                                       0.195454059
#               Rafale.sur.les.10.dernières.minutes
#                                       0.183613415
#                       Vitesse.du.vent.moyen.10.mn
#                                       0.107534794
#                     Direction.du.vent.moyen.10.mn
#                                       0.035673273
#        Précipitations.dans.les.3.dernières.heures
#                                       0.017843161
#                 Variation.de.pression.en.3.heures
#                                       0.016707901
#        Précipitations.dans.les.6.dernières.heures
#                                       0.016338679
#       Précipitations.dans.les.24.dernières.heures
#                                       0.013552382
#             Précipitations.dans.la.dernière.heure
#                                       0.010692291
#       Précipitations.dans.les.12.dernières.heures
#                                       0.006046974
#                     Type.de.tendance.barométrique
#                                       0.004491578
#                                  Pression.station
#                                       0.004182670
#                Variation.de.pression.en.24.heures
#                                       0.001124071
#                            Visibilité.horizontale
#                                       0.001108389
# Plot with title “Loadings de la Composante 6 PLS”
# Plot with title “Loadings de la Composante 7 PLS”

# %% [markdown]
# ## Clustering
